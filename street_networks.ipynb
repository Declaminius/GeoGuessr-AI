# %%
import osmnx as ox
G = ox.graph_from_xml("OSM-Data/nt_highways_uptoresidential.osm")

# %%
G = ox.project_graph(G)

# %%
ox.save_graphml(G, "networks/Australia/Northern Territory.graphml")
print(len(G.nodes), len(G.edges))
ox.plot_graph(G)
# Out:
# 8456 19090
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
print(ox.basic_stats(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(ox.basic_stats(G))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\osmnx\stats.py:360, in basic_stats(G, area, clean_int_tol)
#     358 stats["edge_length_avg"] = stats["edge_length_total"] / stats["m"]
#     359 stats["streets_per_node_avg"] = streets_per_node_avg(G)
# --> 360 stats["streets_per_node_counts"] = streets_per_node_counts(G)
#     361 stats["streets_per_node_proportions"] = streets_per_node_proportions(G)
#     362 stats["intersection_count"] = intersection_count(G)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\osmnx\stats.py:83, in streets_per_node_counts(G)
#      68 """
#      69 Calculate streets-per-node counts.
#      70
#    (...)
#      80     values of how many nodes in the graph have this count
# ...
